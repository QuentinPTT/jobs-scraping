# %%
# scripts/run_scraper.py
from f1_jobs.job_scraper import JobScraper

scraper = JobScraper()
jobs = scraper.scrape_jobs()
## beautiful print
for job in jobs:
    print(job)
    print()
# Out:
# {'job_id': '405', 'job_name': 'Senior Race Engineer', 'department': '600 - Race and Test Engineering', 'employment_status': 'Temps plein', 'location_city': 'Banbury', 'location_state': 'Oxfordshire'}
#
# {'job_id': '408', 'job_name': 'Senior Mechanical Design Engineer', 'department': '200 - Design', 'employment_status': 'Temps plein', 'location_city': 'Maranello', 'location_state': 'Modena'}
#
# {'job_id': '409', 'job_name': 'Senior Aerodynamicist', 'department': '400 - Aerodynamics', 'employment_status': 'Temps plein', 'location_city': 'Maranello', 'location_state': 'Modena'}
#
# {'job_id': '417', 'job_name': 'Junior Aerodynamicist', 'department': '400 - Aerodynamics', 'employment_status': 'Temps plein', 'location_city': 'Maranello', 'location_state': 'Modena'}
#
# {'job_id': '421', 'job_name': 'Enterprise Applications Team Leader', 'department': '955 - Enterprise Applications', 'employment_status': 'Temps plein', 'location_city': 'Banbury', 'location_state': 'Oxfordshire'}
#
# ...

# %%
len(jobs)
# Out:
# 73

# %%
from f1_jobs.website_parsers import parsers

result = parsers[4]['get_jobs']()
result
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\Quent\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\Quent\AppData\Local\Programs\Python\Python312\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# ...
